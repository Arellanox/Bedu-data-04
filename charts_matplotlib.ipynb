# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot([1,2,3,23,12])

# %%
plt.plot([1,2,3,23,12], linewidth=12, label="Random label")

# %%
values_in_y = [120,89,56,172,12,129]
values_in_x = ['Monterrey','Nuevo Leon','CDMX','Jalisco','Puebla','Guerrero']

# %%
plt.bar(values_in_x,values_in_y)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.scatter(values_in_x,values_in_y)
plt.title("sadfasdf")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-9c99b45b48bf> in <module>
#       1 plt.scatter(values_in_x,values_in_y)
# ----> 2 plt.title("sadfasdf")
#
# TypeError: 'str' object is not callable
